# %% [markdown]
# # Optimizing neurally diverse architectures for small and imbalanced subsets of MNIST
#
# * This notebook is for exploring architectural specifications for neurally diverse architectures on a small and imbalanced version of MNIST.
# * The architecture includes pre-branch, branch, and post-branch segments. Neural diversity is implemented specifically at the level of activation function non-linearity and a small wet of "connection functions" (i.e. linear, identity, and element-wise scaling).
# * A highly simplistic form of architectural search based on stochastic hill-climbing with some differential search is included, for your reference.
# * 0.3.7 - added id and elementwise scaling weight functions.
# * 0.3.8 - added training acuracies; do_train is now returning the model with the best validation error.
# * 0.3.9 - added basic DropCircuit.

# %%
version = '_v0p3p9_'

import time
import warnings

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

from sklearn import cluster, datasets, mixture
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler
from itertools import cycle, islice

import torch
import numpy as np
from torch.utils import data
import copy

from __future__ import print_function
import argparse
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable

from IPython.core.debugger import set_trace

# ===============
# Initializations
# ===============

# !pip install torch torchvision

# ===============
# Parameters
# ===============

# --- General framework arguments

args = {}
kwargs = {}
args['num_train_batch'] = 1  # number of MNIST training batches
args['num_valid_batch'] = 10  # number of MNIST validation batches
args['train_batch_size'] = 100   # training batch size
args['valid_batch_size'] = 100   # validation batch size
args['test_batch_size'] = 10
# args['epochs'] = 100  # number of training epochs 
args['lr'] = 1 # 0.1  # 0.01 # learning rate # this is over-written by the solution
args['momentum'] = 0.5 # SGD momentum (default: 0.5); momentum is a moving average of our gradients (helps keep a useful direction)
args['clip_level'] = 0.5  # gradient clip threshold
args['seed']= 1 #random seed
args['log_interval_epoch'] = 1 # display training loss every log_int... epochs
args['cuda'] = True 
args['patience'] = 1000  # stop train. if the valid. err. hasn't improved by this num. of epochs
args['noise_in'] = -1   # 0.5  # 0.15  # amount of noise to add to the training data
args['noise_out'] = -1   #  probability of changing an output label to some random label
args['verbose_train'] = False   # print status of model training?
args['verbose_meta'] = True #  print status of architecture optimization?
args['min_inst_class'] = 5 # minimum number of instances per class in the training set
args['batch_max_tries'] = 10 # max. num. of attempts in extracting data batches
args['save_best_chrom'] = True # False  # save the best chromose in Google Drive?
args['dc_prob_drop'] = 0.5 # 0.5 # probability of dropping a circuit (DropCircuit)
args['prob_sel_branch'] = 0.5 # probability of architectural search selecting/using a branch (this is not DropCircuit) 

# --- Neural architectural limits

args['num_epochs_search'] = 10 # 100  # number of epochs for training during architecture search 
args['num_epochs_test'] = 1000  # num. epochs for training during the final test
limits = {}
limits['min_layer_nodes'] =  10 # 5 # 50
limits['max_layer_nodes'] = 100
limits['max_pre_branch_layers'] = 5 # 3
limits['max_branches'] = 10
limits['max_branch_layers'] = 5  # 3
limits['max_post_branch_layers'] = 5 # 3
limits['lr1_min'] = 0.001
limits['lr1_,max'] = 2
limits['lr2_min'] = 0.001
limits['lr2_,max'] = 2
limits['moment_min'] = 0.001
limits['moment_max'] = 1

# np.random.seed(0)
# torch.manual_seed(0)

num_train_instances = args['num_train_batch'] * args['train_batch_size']
num_valid_instances = args['num_valid_batch'] * args['valid_batch_size']

data_rand_seed = 1 # (other pre-tested seeds: 2, 3)

# ============
# Load dataset
# ============

# Seed creation
torch.manual_seed(data_rand_seed)
np.random.seed(data_rand_seed)

a_data_transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
  
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                   transform=a_data_transform),
    batch_size=args['train_batch_size'], shuffle=True, **kwargs)

test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=a_data_transform),
    batch_size=args['test_batch_size'], shuffle=True, **kwargs)

# Check whether we have enough instances per class
# We want an imbalanced dataset but we don't want any specific label having
# an "insufficient" number of instances.
def check_enough_inst(batches, min_inst_per_class):
  
  # Concatenate training batch output labels
  labels = batches[0][1].numpy()
  for batch_i in range(1,args['num_train_batch']):
    new_labels = batches[batch_i][1].numpy()
    labels = np.concatenate((labels, new_labels))

  labels = labels.tolist()

  # Scan though labels
  for a_label in range(10):  # assuming MNIST, of course
    a_count = labels.count(a_label)
    # If label count is < min_inst_per_class return False
    if a_count < min_inst_per_class:
      return False

  # Return True
  return True


# Prepare data. Extract training and validation batches
# This is where we make the problem "small and imbalanced"
def extract_batches(a_loader, min_inst_per_class, max_tries):

  # Keep trying until you have a required minimum number of instances 
  # per class in the training set (not elegant but ok for the range of 
  # "min_inst_per_class" we need)

  for ti in range(max_tries):

    print('Data extraction trial {}.'.format(ti))

    # Initializations
    train_batches = []
    valid_batches = []
    tot_batch_extract = args['num_train_batch'] + args['num_valid_batch']

    # Extract
    for batch_idx, (data, target) in enumerate(a_loader):

      if batch_idx < args['num_train_batch']:
        train_batches.append((data,target))
      else:
        valid_batches.append((data,target))
        if batch_idx == tot_batch_extract - 1:
          break

    # Check minimum number of instances
    enough_instaces = check_enough_inst(train_batches, min_inst_per_class)
    if enough_instaces:
      return train_batches, valid_batches

  print('It was not possible to create a dataset.')
  print('Consider increasing the overall number of instances, or')
  print('decreasing the minimum instances per class allowed.')
  return [], []


train_batches, valid_batches = extract_batches(train_loader, args['min_inst_class'], args['batch_max_tries'])
if args['verbose_train']:
  print('Extracted {} train_batches, and {} valid_batches.'.format(len(train_batches), len(valid_batches)))

# ===========================
# Display histogram of labels
# ===========================

def disp_hist_labaels(batches):
  # Concatenate training batch output labels
  labels = batches[0][1].numpy()
  for batch_i in range(1,args['num_train_batch']):
    new_labels = batches[batch_i][1].numpy()
    labels = np.concatenate((labels, new_labels))

  num_bins = 10
  n, bins, patches = plt.hist(labels, num_bins, facecolor='blue', alpha=0.5)
  plt.show()

disp_hist_labaels(train_batches)

# ==========================
# Display dataset
# ==========================

# This is not currently used

# Display MNIST instances
# Adapted from # https://github.com/CSCfi/machine-learning-scripts/blob/master/notebooks/pytorch-mnist-mlp.ipynb
def disp_MNIST_inst(num_disp, X_train, y_train):
  pltsize=1
  plt.figure(figsize=(num_disp*pltsize, pltsize))
  for i in range(num_disp):
    plt.subplot(1,num_disp,i+1)
    plt.axis('off')
    plt.imshow(X_train[i,:,:].numpy().reshape(28,28), cmap="gray_r")
    plt.title('Class: '+str(y_train[i].item()))

if args['verbose_train']:
  X_train = train_batches[0][0]
  y_train = train_batches[0][1]

  disp_MNIST_inst(10, X_train, y_train)

  sum_train_0 = X_train[0,:,:].sum()
  min_train_0 = X_train[0,:,:].min()
  max_train_0 = X_train[0,:,:].max()

  print('X_train[0,:,:] --> sum ({}); min ({}); max ({}).'.format(sum_train_0, min_train_0, max_train_0))

# ==========================
# Design model
# ==========================

# "Unseed" the rest
np.random.seed()
a_rand_seed = np.random.randint(0,999999)
torch.manual_seed(a_rand_seed)

# Simple function to scale parameters
# num is assume to be \in [0,1]
def scale_to_range(num,min_val,max_val):
  range = max_val - min_val
  return (num*range)+min_val

# Simple layer for doing elementwise scaling
# Adapated from https://stackoverflow.com/questions/51980654/pytorch-element-wise-filter-layer
class Elem_Scaling_1D(nn.Module):
  def __init__(self, num_nodes, bogus):  # clean-up "bogus"
    super(Elem_Scaling_1D, self).__init__()
    # Initialize
    init_weights = np.random.normal(loc=0, scale=0.5, size=np.shape(num_nodes))
    # Assign
    self.weights = torch.from_numpy(init_weights)
    #self.weights = nn.Parameter(torch.Tensor(1, num_nodes))  # trainable parameter

  def forward(self, x):
    # assuming x is of size num_inst-1-num_nodes
    return x * self.weights  # element-wise multiplication

# Class gradient-based neural diversity machine
class GBNDM(nn.Module):   
    def __init__(self, a_chromosome):   # assuming MNIST
        super(GBNDM, self).__init__()

        # --------- Pre-branch layers 
        self.chromosome = a_chromosome
        self.pre_branch_layers = nn.ModuleList()
        prev_num_out = 28*28
        chrom_ind = 5 # skip over 3 learning rate param., 1 moment. p. (interp./used in training)
        # and 1 exist-or-not (may use in future versions).
        # Each layer is [exist-or-not, id-or-linear, activation function (AF), 2 AF parameters, number of nodes → total: 6 parameters]
        for i in range(limits['max_pre_branch_layers']):
          
          # Extract and interpret parameters
          layer_params_raw = a_chromosome[chrom_ind:chrom_ind+6]
          layer_params_real = self.interp_layer_param(layer_params_raw)
        
          # Decide on whether to create a layer or not
          if i==0:  # the first layer of each segment is done by default
            do_layer = True
          else:
            do_layer = layer_params_real[0]

          if do_layer:
            # Create layer    
            a_layer, prev_num_out = self.create_layer(prev_num_out, layer_params_real)
            # Append layer and update chromosome index
            self.pre_branch_layers.append(a_layer)
            
          chrom_ind += 6

        # --------- Branches
        num_out_pre_branch = prev_num_out

        self.branches = nn.ModuleList()

        # Scan over branches
        final_num_nodes = []  # keep track of the size of the final layer of each branch
        count_branches = 0
        for bi in range(limits['max_branches']):

          # Initialize branch
          branch_layers = nn.ModuleList()

          # Do branch? Always do the first one by default
          if (a_chromosome[chrom_ind] < args['prob_sel_branch']) or (bi == 0):
            do_branch = True
          else: 
            do_branch = False
            
          chrom_ind += 1

          # Scan over branch layers

          if do_branch:  # if doing branch

            this_fin_num_nodes = 0

            count_branches += 1
            
            for li in range(limits['max_branch_layers']):

              # Extract and interpret parameters
              layer_params_raw = a_chromosome[chrom_ind:chrom_ind+6]
              layer_params_real = self.interp_layer_param(layer_params_raw)

              # Decide on whether to create a layer or not
              if li==0:  # the first layer of each branch is done by default
                do_layer = True
                prev_num_out = num_out_pre_branch
              else:
                do_layer = layer_params_real[0]

              if do_layer:
                # print('... temp ... this_fin_num_nodes: {}.'.format(this_fin_num_nodes))
                # Create layer    
                a_layer, prev_num_out = self.create_layer(prev_num_out, layer_params_real)
                # Num_nodes - keep storing the latest one; the last latest is the final layer num_nodes
                this_fin_num_nodes = prev_num_out
                # Append layer and update chromosome index
                branch_layers.append(a_layer)

              chrom_ind += 6

            # Append branch
            final_num_nodes.append(this_fin_num_nodes)
            #print('final_num_nodes: {}.'.format(final_num_nodes))
            self.branches.append(branch_layers)

          else: # if not doing branch you still need to increment chromosome index

            chrom_ind += 6*limits['max_branch_layers']

        self.num_branches = count_branches
        self.dc_prob_activ = 1 - args['dc_prob_drop'] # probability of using a circuit
        self.tot_nodes_branch_final = sum(final_num_nodes)
        
        # --------- Post-branch layers

        prev_num_out = self.tot_nodes_branch_final
        
        # --- Create post-branch layers

        chrom_ind += 1  # skip over the parameter pertaining to the existence or not of the post-branch segment

        self.post_branch_layers = nn.ModuleList()
        
        # Each layer is [exist-or-not, id-or-linear, activation function (AF), 2 AF parameters, number of nodes → total: 6 parameters]
        for li in range(limits['max_post_branch_layers']):
          
          # Extract and interpret parameters
          layer_params_raw = a_chromosome[chrom_ind:chrom_ind+6]
          layer_params_real = self.interp_layer_param(layer_params_raw)
        
          # Decide on whether to create a layer or not
          if li==0:  # the first layer of each segment is done by default
            do_layer = True
          else:
            do_layer = layer_params_real[0]

          if do_layer:
            # Create layer    
            a_layer, prev_num_out = self.create_layer(prev_num_out, layer_params_real)
            # Append layer and update chromosome index
            self.post_branch_layers.append(a_layer)
            
          chrom_ind += 6

        # Create a final layer
        self.final_layer = nn.Linear(prev_num_out, 10)

    def forward(self, x, dc_mask = None):
        
        x = x.view(-1, 28*28)

        # Apply pre-branch layers
        for pi, a_layer in enumerate(self.pre_branch_layers):
          #print('Pre-layer {}'.format(pi))
          # if isinstance(a_layer, Elem_Scaling_1D):
          #   set_trace()
          x = a_layer(x)

        # Apply branches
        branch_finals = []
        for bi, a_branch in enumerate(self.branches):
          #print('Branch {}'.format(bi))
          
          z = x

          for a_layer in a_branch:
            # if isinstance(a_layer, Elem_Scaling_1D):
            #   set_trace()
            z = a_layer(z)
          
          if self.training:
            z = (dc_mask[bi] * z) / self.dc_prob_activ  # if training apply DropCircuit
          
          branch_finals.append(z)

        # Concatenate multi-branch final layers
        x = torch.cat(branch_finals,dim=1)

        # if not(self.training): # if not training then testing/evaluating
        #   x = self.dc_prob_activ * x  # scaling due to DropCircuit
      

        # Apply post-branch layers
        for pi, a_layer in enumerate(self.post_branch_layers):
          #print('Post-layer: {}'.format(pi))
          # if isinstance(a_layer, Elem_Scaling_1D):
          #   set_trace()
          x = a_layer(x)

        # Apply final layer
        x = self.final_layer(x)
               
        return F.log_softmax(x, dim=1)


    # Method for interpreting layer parameters
    # Each layer is [exist-or-not, id-or-linear, activation function (AF), 2 AF parameters, number of nodes → total: 6 parameters]
    def interp_layer_param(self, layer_params_raw):
      # Exist or not
      if layer_params_raw[0] < 0.5:
        exist = False
      else:
        exist = True
      # Weight function
      tot_weight_func = 3
      if layer_params_raw[1] < 0.6: # or ... (1/tot_weight_func):  
        weight_func_sel = 'linear'
      elif layer_params_raw[1] < 0.8: # or ... (2/tot_weight_func):
        weight_func_sel = 'elem_scale'
      else:
        weight_func_sel = 'id'
      # activation function
      tot_node_func = 22
      if layer_params_raw[2] < (1/tot_node_func):
        activ_func = 'ReLU'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (2/tot_node_func):
        activ_func = 'Hardshrink'
        param_1 = scale_to_range(layer_params_raw[3],0,2)
        param_2 = -1
      elif layer_params_raw[2] < (3/tot_node_func):
        activ_func = 'Hardtanh'
        param_1 = scale_to_range(layer_params_raw[3],0,2)
        param_2 = scale_to_range(layer_params_raw[4],0,2)
        if param_1 > param_2:  # param_1 is min_val; param_2 is max_val
          tmp_val = param_1
          param_1 = param_2
          param_2 = tmp_val
        elif param_1 == param_2:
          param_2 += 0.1
      elif layer_params_raw[2] < (4/tot_node_func):
        activ_func = 'LeakyReLU'
        param_1 = scale_to_range(layer_params_raw[3],0,1)
        param_2 = -1
      elif layer_params_raw[2] < (5/tot_node_func):
        activ_func = 'LogSigmoid'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (6/tot_node_func):
        activ_func = 'PReLU'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (7/tot_node_func):
        activ_func = 'ELU'
        param_1 = scale_to_range(layer_params_raw[3],0,2)
        param_2 = -1
      elif layer_params_raw[2] < (8/tot_node_func):
        activ_func = 'ReLU6'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (9/tot_node_func):
        activ_func = 'RReLU'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (10/tot_node_func):
        activ_func = 'SELU'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (11/tot_node_func):
        activ_func = 'CELU'
        param_1 = scale_to_range(layer_params_raw[3],0,2)
        param_2 = -1
      elif layer_params_raw[2] < (12/tot_node_func):
        activ_func = 'GELU'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (13/tot_node_func):
        activ_func = 'Sigmoid'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (14/tot_node_func):
        activ_func = 'Softplus'
        param_1 = scale_to_range(layer_params_raw[3],0,2)
        param_2 = scale_to_range(layer_params_raw[4],0,40)
      elif layer_params_raw[2] < (15/tot_node_func):
        activ_func = 'Softshrink'
        param_1 = scale_to_range(layer_params_raw[3],0,2)
        param_2 = -1
      elif layer_params_raw[2] < (16/tot_node_func):
        activ_func = 'Softsign'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (17/tot_node_func):
        activ_func = 'Tanh'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (18/tot_node_func):
        activ_func = 'Tanhshrink'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (19/tot_node_func):
        activ_func = 'Threshold'
        param_1 = scale_to_range(layer_params_raw[3],0,2)
        param_2 = scale_to_range(layer_params_raw[4],0,2)
      elif layer_params_raw[2] < (20/tot_node_func):
        activ_func = 'Softmin'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (21/tot_node_func):
        activ_func = 'Softmax'
        param_1 = -1
        param_2 = -1
      else: 
        activ_func = 'None'
        param_1 = -1
        param_2 = -1

      # number of nodes
      num_nodes = scale_to_range(layer_params_raw[5], limits['min_layer_nodes'], limits['max_layer_nodes'])
      num_nodes = num_nodes.astype(int)

      return (exist, weight_func_sel, activ_func, param_1, param_2, num_nodes)

    # Method for creating a layer
    # layer_params_real format: (exist, weight_func_sel, activ_func, param_1, param_2, num_nodes)
    def create_layer(self, prev_num_out, layer_params_real):
      
      exist, weight_func_sel, activ_func, param_1, param_2, num_nodes = layer_params_real
      
      # wf_param1/wf_param2 --> not elegant 
      if weight_func_sel == 'linear':
        weight_func = nn.Linear
        num_nodes_in = prev_num_out
        num_nodes_out = num_nodes
        wf_param1 = num_nodes_in
        wf_param2 = num_nodes_out
      elif weight_func_sel == 'id':
        weight_func = nn.Identity
        num_nodes_in = prev_num_out
        num_nodes_out = prev_num_out
        wf_param1 = num_nodes_in
        wf_param2 = num_nodes_out
      else:  # 'elem_scale'
        weight_func = Elem_Scaling_1D
        num_nodes_in = prev_num_out
        num_nodes_out = prev_num_out
        wf_param1 = num_nodes_in
        wf_param2 = num_nodes_out
        
      if activ_func == 'ReLU':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.ReLU())
      elif activ_func == 'Hardshrink':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Hardshrink(param_1))
      elif activ_func == 'Hardtanh':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Hardtanh(param_1, param_2))
      elif activ_func == 'LeakyReLU':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.LeakyReLU(param_1))
      elif activ_func == 'LogSigmoid':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.LogSigmoid())
      elif activ_func == 'PReLU':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.PReLU())
      elif activ_func == 'ELU':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.ELU(param_1))
      elif activ_func == 'ReLU6':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.ReLU6())
      elif activ_func == 'RReLU':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.RReLU())
      elif activ_func == 'SELU':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.SELU())
      elif activ_func == 'CELU':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.CELU(param_1))
      elif activ_func == 'GELU':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.ReLU())  # for some reason GELU is not present; revert later if relevant
      elif activ_func == 'Sigmoid':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Sigmoid())
      elif activ_func == 'Softplus':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Softplus(param_1, param_2))
      elif activ_func == 'Softshrink':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Softplus(param_1))
      elif activ_func == 'Softsign':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Softsign())
      elif activ_func == 'Tanh':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Tanh())
      elif activ_func == 'Tanhshrink':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Tanhshrink())
      elif activ_func == 'Threshold':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Threshold(param_1, param_2))
      elif activ_func == 'Softmin':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Softmin())
      elif activ_func == 'Softmax':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Softmax())
      else:
        a_layer = weight_func(wf_param1, wf_param2)

      return a_layer, num_nodes_out


# Generate a random chromosome where each param. is \in [0,1)
def gen_rand_chromosome(num_param):
  chrom = np.random.rand(num_param)
  return chrom

# ==========================
# Train and test functions
# ==========================

# Create a random mask for DropCircuit
def make_mask(num_circuits, prob_drop):
  rand_vals = np.random.rand(num_circuits)
  decisions = rand_vals >= prob_drop
  a_mask = np.ones(num_circuits)*decisions
  # Must have at least one circuit active
  if np.sum(a_mask) == 0:
    rand_index = np.random.randint(num_circuits)
    a_mask[rand_index] = 1.0

  return torch.from_numpy(a_mask)

def train_one_epoch(a_model, optimizer, epoch, batches):

  a_model.train()
  for batch_idx, (data, target) in enumerate(batches):
      if args['cuda']:
          data, target = data.cuda(), target.cuda()
      # Variables in Pytorch are differentiable. 
      
      data, target = Variable(data), Variable(target)
      #This will zero out the gradients for this batch. 
      optimizer.zero_grad()
      
      # Create DropCircuit mask
      dc_mask = make_mask(a_model.num_branches, args['dc_prob_drop'])
      
      output = a_model(data, dc_mask)

      # Calculate the negative log likelihood loss.
      loss = F.nll_loss(output, target)
      #dloss/dx for every Variable 
      loss.backward()
      # Gradient clipping
      torch.nn.utils.clip_grad_norm_(a_model.parameters(), args['clip_level'])
      #to do a one-step update on our parameter.
      optimizer.step()
      #Print out the loss periodically. 

  if args['verbose_train']:
    if epoch % args['log_interval_epoch'] == 0:
      print('Epoch: {}. Latest loss: {}.'.format(epoch, loss.data))

# Compute accuracy
# The argument (data_source) of this function can be a data_loader or a list of batches (previously extracted) 
def comp_accuracy(a_model, data_source, src_num_instances):
    a_model.eval()
    a_loss = 0
    correct = 0
    preds = torch.zeros(0)
    first = True
    for a_data_in, a_data_out in data_source:
        if args['cuda']:
            a_data_in, a_data_out = a_data_in.cuda(), a_data_out.cuda()
        a_data_in, a_data_out = Variable(a_data_in), Variable(a_data_out)
        output = a_model(a_data_in)

        a_loss += F.nll_loss(output, a_data_out, reduction='sum').data # sum up batch loss
        pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
        if first:
          preds = pred
          first = False
        else:
          preds = torch.cat((preds, pred),0)

        correct += pred.eq(a_data_out.data.view_as(pred)).long().cpu().sum()

    # Compute and return accuracy
    if type(data_source) == list:  # case: list of batches
      result = 100. * (correct.numpy()/ src_num_instances)
    else: # case: data_loader
      result = 100. * (correct.numpy()/ len(data_source.dataset))
    return result



# ==========================
# Train and test functions
# ==========================

# Compute the number of parameters in a chromose (depends on limits)
def comp_num_chrom_param(limits):
  # Num. of training parameters
  tot_train_param = 4 # lr1, lr2, lr2 prop, momentum
  # Num. of pre-branch parameters
  tot_pre_branch = 1+(6*limits['max_pre_branch_layers']) # exist-or-not, layer params.
  # Num. of branch parameters
  tot_branch = (1+(6*limits['max_branch_layers']))*limits['max_branches']
  # Num. of post-branch parameters
  tot_post_branch = 1+(6*limits['max_post_branch_layers'])

  return tot_train_param+tot_pre_branch+tot_branch+tot_post_branch

# Interpret learning rate and momentum parameters
def interp_lrm(params):
  lr1 = scale_to_range(params[0], limits['lr1_min'], limits['lr1_,max'])
  lr2 = scale_to_range(params[1], limits['lr2_min'], limits['lr2_,max'])
  if lr1 < lr2:
    temp = lr1
    lr1 = lr2
    lr2 = temp
  lr2_epoch = (np.round(params[2]*args['num_epochs_search'])).astype(int)
  a_decr = (lr1-lr2)/lr2_epoch
  a_momentum = scale_to_range(params[3], limits['moment_min'], limits['moment_max'])
  return lr1, lr2, lr2_epoch, a_momentum, a_decr

# Chromosome evaluation (more efficient than do_training)
# Function to train a specific model
# Early stopping, or returning best validation model, is not implemented 
def do_eval_chrom(a_model, train_params, num_epochs):

  # Extract basic information
  lr1, lr2, lr2_epoch, a_momentum, lr_decr = train_params  
  args['lr'] = lr1
  args['momentum'] = a_momentum
  
  optimizer = optim.SGD(a_model.parameters(), lr=args['lr'], momentum=args['momentum'])
  valid_accurs = []
  train_accurs = []
  train_start_time = time.time()
  for epoch in range(1, num_epochs + 1):

    if args['verbose_train']:
      print('Epoch {} learning rate: {}.'.format(epoch, args['lr']))

    train_one_epoch(a_model, optimizer, epoch, train_batches)
    
    a_train_accur = comp_accuracy(a_model, train_batches, num_train_instances)
    if args['verbose_train']:
      print('Training accuracy: {}%.'.format(a_train_accur))
    train_accurs.append(a_train_accur)
    
    a_valid_accur = comp_accuracy(a_model, valid_batches, num_valid_instances)
    if args['verbose_train']:
      print('Validation accuracy: {}%.'.format(a_valid_accur))
    valid_accurs.append(a_valid_accur)

    # Decrement learning rate
    if epoch < lr2_epoch:
        args['lr'] -= lr_decr
        for param_group in optimizer.param_groups:
          param_group['lr'] = args['lr']

  train_elapsed_time = time.time() - train_start_time
  print('The training process took {} seconds.'.format(train_elapsed_time))

  return a_model, valid_accurs, train_accurs

# Function to train a specific model
# Early stopping, or returning best validation model, is not implemented 
def do_training(a_model, train_params, num_epochs):

  lr1, lr2, lr2_epoch, a_momentum, lr_decr = train_params  
  args['lr'] = lr1
  args['momentum'] = a_momentum

  optimizer = optim.SGD(a_model.parameters(), lr=args['lr'], momentum=args['momentum'])
  best_valid_accur = 0
  best_model = type(a_model)(a_model.chromosome) # get a new instance
  valid_accurs = []
  train_accurs = []
  train_start_time = time.time()
  for epoch in range(1, num_epochs + 1):

    if args['verbose_train']:
      print('Epoch {} learning rate: {}.'.format(epoch, args['lr']))

    train_one_epoch(a_model, optimizer, epoch, train_batches)
    
    a_train_accur = comp_accuracy(a_model, train_batches, num_train_instances)
    if args['verbose_train']:
      print('Training accuracy: {}%.'.format(a_train_accur))
    train_accurs.append(a_train_accur)
    
    a_valid_accur = comp_accuracy(a_model, valid_batches, num_valid_instances)
    if args['verbose_train']:
      print('Validation accuracy: {}%.'.format(a_valid_accur))
    valid_accurs.append(a_valid_accur)
    if a_valid_accur > best_valid_accur:
      best_valid_accur = a_valid_accur
      # best_model.load_state_dict(a_model.state_dict()) # copy weights and stuff
      best_model = copy.deepcopy(a_model)

    # Decrement learning rate
    if epoch < lr2_epoch:
        args['lr'] -= lr_decr
        for param_group in optimizer.param_groups:
          param_group['lr'] = args['lr']

  train_elapsed_time = time.time() - train_start_time
  print('The training process took {} seconds.'.format(train_elapsed_time))

  if args['cuda']:
      best_model.cuda()

  return a_model, best_model, valid_accurs, train_accurs

# ================================
# Architectureal search
# ================================

# Artificial Intelligence Methods students should focus on the code below.
# You should keep the neural network code unchaged. This is crucial for 
# comparison purposes. In other words, focus only on modifying the architecture
# search code below.

# --- Architectural search parameters
meta = {}
meta['max_rs_iter'] = 50 # 10  # initial random search
meta['max_shc_iter'] = 20 # 20 # 40  # stochastic hill climbing iterations
meta['num_neighbours'] = 20 # 16 
meta['neighbour_range'] = 0.2  # 0.2  # mutation rate for stochastic hill-climbing
meta['num_differential_sol'] = 10 # number of differential evolution solutions
meta['diff_lr'] = 0.5 # 0.1 # learning rate for differential search

meta_rs_valids = []
best_model = None
best_chromosome = None
best_model_accur = 0

# Prepare model
def prepare_model(a_rand_chrom):
  # Initialize chromosome and model
  model = GBNDM(a_rand_chrom)
  
  if args['cuda']:
      model.cuda()

  # Interpret learning rates and momentum
  lr1, lr2, lr2_epoch, a_momentum, lr_decr = interp_lrm(a_rand_chrom[0:4])
  train_params = (lr1, lr2, lr2_epoch, a_momentum, lr_decr)
  args['momentum'] = a_momentum
  if args['verbose_train']:
    print('lr1: {}'.format(lr1))
    print('lr2: {}'.format(lr2))
    print('lr2_epoch: {}'.format(lr2_epoch))
    print('a_momentum: {}'.format(a_momentum))
    print('a_decr: {}'.format(a_decr))

  return model, train_params

# Start with a small random search
print('Initital random search ...')
for rsi in range(meta['max_rs_iter']):

  if args['verbose_meta']:
    print('Search iteration {}.'.format(rsi+1))

  num_chrom_param = comp_num_chrom_param(limits)
  
  a_rand_chrom = gen_rand_chromosome(num_chrom_param)

  # --- Actual training
  model, train_params = prepare_model(a_rand_chrom)
  model, valid_accurs, train_accurs = do_eval_chrom(model, train_params, args['num_epochs_search'])
  best_valid_accur = max(valid_accurs)
  print('Best validation accuracy: {}%.'.format(best_valid_accur))

  # Store best model
  if best_valid_accur > best_model_accur:
    best_model_accur = best_valid_accur
    best_model = model
    best_train_params = train_params
    best_chromosome = a_rand_chrom

  meta_rs_valids.append(best_valid_accur)

print('*****************************************************')
print('Best accuracy after initial random search: {}'.format(best_model_accur))
print('*****************************************************')

if args['verbose_meta']:
  print('Best validation errors:')
  print(meta_rs_valids)

# # --- Stochastic hill climbing

num_chrom_params = best_chromosome.shape[0]

# Function for creating one neighbour
def create_a_neighbour(a_chromosome, neighbour_range, num_chrom_params):
  # Create mutation vector
  mutat_vec = (np.random.rand(num_chrom_params)*neighbour_range)-(neighbour_range/2)
  # Add mutation vector
  new_chromosome = a_chromosome + mutat_vec
  # Clip
  np.clip(new_chromosome, 0, 0.99999999999, out=new_chromosome)

  return new_chromosome

# Evaluate a list of chromosomes
def eval_chromosomes(list_chromosomes,num_chrom_params):
  
  # best_model_accur, best_chromosome, best_model, best_train_params = best_res
  
  best_model_accur = 0
  best_chromosome = None
  best_model = None
  best_train_params = None


  num_chrom = len(list_chromosomes)
  mat_chrom_acur = np.zeros((num_chrom, 1+num_chrom_params))
  neighb_valid_accurs = []

  for ci, a_chrom in enumerate(list_chromosomes):
    if args['verbose_meta']:
      print('Chromosome {} ...'.format(ci))
    # --- Actual training
    model, train_params = prepare_model(a_chrom)
    model, valid_accurs, train_accurs = do_eval_chrom(model, train_params, args['num_epochs_search'])
    best_valid_accur = max(valid_accurs)
    # Store chromosome and accuracy
    mat_chrom_acur[ci,0] = best_valid_accur
    mat_chrom_acur[ci,1:] = a_chrom
    print('Best validation accuracy: {}%.'.format(best_valid_accur))
    neighb_valid_accurs.append(best_valid_accur)
    if best_valid_accur > best_model_accur:
      best_model_accur = best_valid_accur
      best_chromosome = a_chrom
      best_model = model
      best_train_params = train_params
      if args['verbose_meta']:
        print('*** Improving validation accuracy: {}.'.format(best_model_accur))

  best_res = (best_model_accur, best_chromosome, best_model, best_train_params)
  return best_res, mat_chrom_acur
      
    
# Function for creating a list of neighbours
def create_neighbours(a_chromosome, meta, num_chrom_params):
  neighbours = []
  # Scan through number of neighbours
  for ni in range(meta['num_neighbours']):
    # Create neighbour
    a_neighb = create_a_neighbour(a_chromosome, meta['neighbour_range'], num_chrom_params)
    # Append neighbour
    neighbours.append(a_neighb)

  return neighbours

# Simple differential search
def do_diff_chrom_v1(mat_chrom_accur, num_new_sol):
  
  # Initialize new chromosomes
  num_chrom = mat_chrom_accur.shape[0]
  if num_new_sol >= num_chrom:
    num_new_sol = num_chrom-1
  new_chromosomes = []

  # Sort the array of chromosomes based on the first column (contains accur.)
  mat_chrom_accur = mat_chrom_accur[(-mat_chrom_accur[:,0]).argsort()]
  # print(mat_chrom_accur[:,0:4])
  # Extract first/best chromosome
  best_chrom = mat_chrom_accur[0,1:]
  # Scan through new solutions
  for si in range(num_new_sol):  
    # Extract next best chrom
    next_best_chrom = mat_chrom_accur[1+si,1:]
    # Compute differential
    a_diff = best_chrom - next_best_chrom
    # Add differential whilst applying a learning rate
    a_new_chrom = best_chrom + (meta['diff_lr']*a_diff)
    np.clip(a_new_chrom, 0, 0.99999999999, out=a_new_chrom)
    # Store new solution 
    new_chromosomes.append(a_new_chrom)

  return new_chromosomes


# Architectural search iterations

best_res = (best_model_accur, best_chromosome, best_model, best_train_params)

meta_start_time = time.time()
for shci in range(meta['max_shc_iter']):

  best_model_accur, best_chromosome, best_model, best_train_params = best_res

  if args['verbose_meta']:
    print('======================================')
    print('Stochastic hill-climbing iteration {}.'.format(shci))
    print('======================================')
    print('Best accuracy so far: {}'.format(best_model_accur))
    print('======================================')
  # --- Create a set of stochastic neighbours from the current best model
  chrom_neighbors = create_neighbours(best_chromosome, meta, num_chrom_params)
  # Test validation accuracies of neighbours
  new_res, mat_chrom_acur = eval_chromosomes(chrom_neighbors,num_chrom_params)
  if new_res[0] > best_res[0]:
    best_res = new_res
  print('***********************************************')
  print('Best accuracy after random mutation: {}'.format(new_res[0]))
  print('***********************************************')
  
  # --- Simple differential search
  print('***** Differential Search *********************')
  diff_chromosomes = do_diff_chrom_v1(mat_chrom_acur, meta['num_differential_sol'])
  new_res, mat_chrom_acur = eval_chromosomes(diff_chromosomes,num_chrom_params)
  if new_res[0] > best_res[0]:
    best_res = new_res
  print('***********************************************')
  print('Best accuracy after differential search: {}'.format(new_res[0]))
  print('***********************************************')

meta_elapsed_time = time.time() - meta_start_time
if args['verbose_meta']:
  print('=====================================================')
  print('Architectural optimization total time: {}.'.format(meta_elapsed_time))
  print('=====================================================')
  

# ==========================
# Test final model / Visualize predictions
# ==========================

def final_test(a_model):
    a_model.eval()
    test_loss = 0
    correct = 0
    test_preds = torch.zeros(0)
    first = True
    for test_data_in, test_data_out in test_loader: 

        if args['cuda']:
            test_data_in, test_data_out = test_data_in.cuda(), test_data_out.cuda()
                
        test_data_in, test_data_out = Variable(test_data_in), Variable(test_data_out)
        output = a_model(test_data_in)
        test_loss += F.nll_loss(output, test_data_out, reduction='sum').data # sum up batch loss

        pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
        if first:
          test_preds = pred
          first = False
        else:
          test_preds = torch.cat((test_preds, pred),0)

        correct += pred.eq(test_data_out.data.view_as(pred)).long().cpu().sum()

    # Print test accuracy
    test_loss /= len(test_loader.dataset)
    accuracy = 100. * correct / len(test_loader.dataset)
    print('\nTest set: Average loss: {:.4f}, Accuracy (at final epoch): {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset), accuracy))

    return accuracy

# Final visualization
print('======================================')
print('Best accuracy so far: {}'.format(best_res[0]))
print('======================================')
print('Computing the final test ...')
best_model_accur, best_chromosome, best_model, best_train_params = best_res
final_model, best_valid_model, valid_accurs, train_accurs = do_training(best_model, best_train_params, args['num_epochs_test'])
print('=====================================')
print('Training accuracies')
print('=====================================')
print(train_accurs)
print('=====================================')
print('Best training parameters')
print('=====================================')
print(best_train_params)
print('=====================================')
print('Best model')
print('=====================================')
print(best_valid_model)
print('=====================================')
print('Test accuracies')
print('=====================================')
print('Model with best validation accuracy: ')
accur_valid = final_test(best_valid_model)
print('Model at the end of training: ')
accur_final = final_test(final_model)

max_accur = int(max(accur_valid, accur_final))

# --- Saving the best chromosome as a csv file
if args['save_best_chrom']:

  print('Saving the best chromosome in the root directory (My Drive) ...')

  from datetime import datetime
  from numpy import asarray
  from numpy import savetxt
  import numpy as np
  from google.colab import drive

  drive.mount('/content/gdrive/')

  def get_date_time_str():
    now = datetime.now() # current date and time
    return now.strftime("%d%m%Y_%H%M")

  # Create filename
  path = '/content/gdrive/My Drive/'
  filename = 'chrom_' + get_date_time_str() + version + str(max_accur)
  savetxt(path+filename, best_chromosome, delimiter=',')
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (1.4.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (0.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.17.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.12.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision) (6.2.2)
# Data extraction trial 0.
# Data extraction trial 1.
# Initital random search ...
# Search iteration 1.
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:100: UserWarning: Implicit dimension choice for softmin has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# The training process took 0.3658912181854248 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 2.
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:100: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# The training process took 0.23314976692199707 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 3.
# The training process took 0.33560609817504883 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 4.
# The training process took 0.23266172409057617 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 5.
# The training process took 0.33805394172668457 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 6.
# The training process took 0.30764031410217285 seconds.
# Best validation accuracy: 10.7%.
# Search iteration 7.
# The training process took 0.24610090255737305 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 8.
# The training process took 0.2504563331604004 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 9.
# The training process took 0.3062922954559326 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 10.
# The training process took 0.25991249084472656 seconds.
# Best validation accuracy: 10.9%.
# Search iteration 11.
# The training process took 0.2836449146270752 seconds.
# Best validation accuracy: 10.7%.
# Search iteration 12.
# The training process took 0.2614099979400635 seconds.
# Best validation accuracy: 10.9%.
# Search iteration 13.
# The training process took 0.29378294944763184 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 14.
# The training process took 0.2986724376678467 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 15.
# The training process took 0.17034220695495605 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 16.
# The training process took 0.3916964530944824 seconds.
# Best validation accuracy: 10.5%.
# Search iteration 17.
# The training process took 0.4152858257293701 seconds.
# Best validation accuracy: 10.9%.
# Search iteration 18.
# The training process took 0.2946896553039551 seconds.
# Best validation accuracy: 10.9%.
# Search iteration 19.
# The training process took 0.3230326175689697 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 20.
# The training process took 0.2577955722808838 seconds.
# Best validation accuracy: 10.7%.
# Search iteration 21.
# The training process took 0.2050924301147461 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 22.
# The training process took 0.2239677906036377 seconds.
# Best validation accuracy: 10.7%.
# Search iteration 23.
# The training process took 0.29362058639526367 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 24.
# The training process took 0.23085737228393555 seconds.
# Best validation accuracy: 10.7%.
# Search iteration 25.
# The training process took 0.29802656173706055 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 26.
# The training process took 0.26633763313293457 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 27.
# The training process took 0.29627466201782227 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 28.
# The training process took 0.1882174015045166 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 29.
# The training process took 0.2221386432647705 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 30.
# The training process took 0.29796552658081055 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 31.
# The training process took 0.20975995063781738 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 32.
# The training process took 0.2603769302368164 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 33.
# The training process took 0.3050532341003418 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 34.
# The training process took 0.26697325706481934 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 35.
# The training process took 0.3029358386993408 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 36.
# The training process took 0.3140592575073242 seconds.
# Best validation accuracy: 10.9%.
# Search iteration 37.
# The training process took 0.20831084251403809 seconds.
# Best validation accuracy: 10.9%.
# Search iteration 38.
# The training process took 0.21863627433776855 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 39.
# The training process took 0.3326377868652344 seconds.
# Best validation accuracy: 10.9%.
# Search iteration 40.
# The training process took 0.3296780586242676 seconds.
# Best validation accuracy: 10.9%.
# Search iteration 41.
# The training process took 0.3641231060028076 seconds.
# Best validation accuracy: 10.9%.
# Search iteration 42.
# The training process took 0.38446688652038574 seconds.
# Best validation accuracy: 10.7%.
# Search iteration 43.
# The training process took 0.362138032913208 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 44.
# The training process took 0.37581634521484375 seconds.
# Best validation accuracy: 10.7%.
# Search iteration 45.
# The training process took 0.2554755210876465 seconds.
# Best validation accuracy: 10.9%.
# Search iteration 46.
# The training process took 0.269977331161499 seconds.
# Best validation accuracy: 10.9%.
# Search iteration 47.
# The training process took 0.27754926681518555 seconds.
# Best validation accuracy: 10.7%.
# Search iteration 48.
# The training process took 0.40073299407958984 seconds.
# Best validation accuracy: 10.5%.
# Search iteration 49.
# The training process took 0.2627723217010498 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 50.
# The training process took 0.2691009044647217 seconds.
# Best validation accuracy: 10.7%.
# *****************************************************
# Best accuracy after initial random search: 10.9
# *****************************************************
# Best validation errors:
# [9.8, 9.8, 9.8, 9.8, 9.8, 10.7, 9.8, 9.8, 9.8, 10.9, 10.7, 10.9, 9.8, 9.8, 9.8, 10.5, 10.9, 10.9, 9.8, 10.7, 9.8, 10.7, 9.8, 10.7, 9.8, 9.8, 9.8, 9.8, 9.8, 9.8, 9.8, 9.8, 9.8, 9.8, 9.8, 10.9, 10.9, 9.8, 10.9, 10.9, 10.9, 10.7, 9.8, 10.7, 10.9, 10.9, 10.7, 10.5, 9.8, 10.7]
# ======================================
# Stochastic hill-climbing iteration 0.
# ======================================
# Best accuracy so far: 10.9
# ======================================
# Chromosome 0 ...
# The training process took 0.255634069442749 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 1 ...
# The training process took 0.21890735626220703 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 2 ...
# The training process took 0.2353959083557129 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 3 ...
# The training process took 0.27989840507507324 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 4 ...
# The training process took 0.24753475189208984 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 5 ...
# The training process took 0.27167367935180664 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 6 ...
# The training process took 0.23990154266357422 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 7 ...
# The training process took 0.23984050750732422 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 8 ...
# The training process took 0.2591891288757324 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 9 ...
# The training process took 0.2838623523712158 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 10 ...
# The training process took 0.23760342597961426 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 11 ...
# The training process took 0.25118231773376465 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 12 ...
# The training process took 0.21519994735717773 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 13 ...
# The training process took 0.26187872886657715 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 14 ...
# The training process took 0.25350403785705566 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 15 ...
# The training process took 0.26923060417175293 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 16 ...
# The training process took 0.27602648735046387 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 17 ...
# The training process took 0.2555873394012451 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 18 ...
# The training process took 0.2668004035949707 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 19 ...
# The training process took 0.2669715881347656 seconds.
# Best validation accuracy: 10.9%.
# ***********************************************
# Best accuracy after random mutation: 10.9
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.2538275718688965 seconds.
# Best validation accuracy: 10.7%.
# *** Improving validation accuracy: 10.7.
# Chromosome 1 ...
# The training process took 0.2614939212799072 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 2 ...
# The training process took 0.2457261085510254 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 3 ...
# The training process took 0.2528419494628906 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 4 ...
# The training process took 0.2579314708709717 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 5 ...
# The training process took 0.2692549228668213 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 6 ...
# The training process took 0.2685883045196533 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 7 ...
# The training process took 0.2224254608154297 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 8 ...
# The training process took 0.2523975372314453 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 9 ...
# The training process took 0.2373819351196289 seconds.
# Best validation accuracy: 9.8%.
# ***********************************************
# Best accuracy after differential search: 10.9
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 1.
# ======================================
# Best accuracy so far: 10.9
# ======================================
# Chromosome 0 ...
# The training process took 0.27956628799438477 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 1 ...
# The training process took 0.2265946865081787 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 2 ...
# The training process took 0.26880359649658203 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 3 ...
# The training process took 0.26065778732299805 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 4 ...
# The training process took 0.2767908573150635 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 5 ...
# The training process took 0.24270081520080566 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 6 ...
# The training process took 0.24491429328918457 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 7 ...
# The training process took 0.26569151878356934 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 8 ...
# The training process took 0.2643256187438965 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 9 ...
# The training process took 0.26311421394348145 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 10 ...
# The training process took 0.23063015937805176 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 11 ...
# The training process took 0.29154133796691895 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 12 ...
# The training process took 0.23804640769958496 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 13 ...
# The training process took 0.2626209259033203 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 14 ...
# The training process took 0.23233294486999512 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 15 ...
# The training process took 0.23368477821350098 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 16 ...
# The training process took 0.2810652256011963 seconds.
# Best validation accuracy: 10.8%.
# Chromosome 17 ...
# The training process took 0.25299811363220215 seconds.
# Best validation accuracy: 11.0%.
# *** Improving validation accuracy: 11.0.
# Chromosome 18 ...
# The training process took 0.22272276878356934 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 19 ...
# The training process took 0.2766869068145752 seconds.
# Best validation accuracy: 10.9%.
# ***********************************************
# Best accuracy after random mutation: 11.0
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.25756382942199707 seconds.
# Best validation accuracy: 10.7%.
# *** Improving validation accuracy: 10.7.
# Chromosome 1 ...
# The training process took 0.23973321914672852 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 2 ...
# The training process took 0.2708003520965576 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 3 ...
# The training process took 0.2614290714263916 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 4 ...
# The training process took 0.26349830627441406 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 5 ...
# The training process took 0.2636082172393799 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 6 ...
# The training process took 0.2573971748352051 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 7 ...
# The training process took 0.26892852783203125 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 8 ...
# The training process took 0.24176931381225586 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 9 ...
# The training process took 0.2537870407104492 seconds.
# Best validation accuracy: 10.7%.
# ***********************************************
# Best accuracy after differential search: 10.9
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 2.
# ======================================
# Best accuracy so far: 11.0
# ======================================
# Chromosome 0 ...
# The training process took 0.2656397819519043 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 1 ...
# The training process took 0.19938302040100098 seconds.
# Best validation accuracy: 65.2%.
# *** Improving validation accuracy: 65.2.
# Chromosome 2 ...
# The training process took 0.2531304359436035 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 3 ...
# The training process took 0.26363086700439453 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 4 ...
# The training process took 0.27660679817199707 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 5 ...
# The training process took 0.270371675491333 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 6 ...
# The training process took 0.2741401195526123 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 7 ...
# The training process took 0.22485756874084473 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 8 ...
# The training process took 0.2670469284057617 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 9 ...
# The training process took 0.2888212203979492 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 10 ...
# The training process took 0.25865602493286133 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 11 ...
# The training process took 0.25074243545532227 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 12 ...
# The training process took 0.2856423854827881 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 13 ...
# The training process took 0.24318456649780273 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 14 ...
# The training process took 0.286388635635376 seconds.
# Best validation accuracy: 12.5%.
# Chromosome 15 ...
# The training process took 0.28614282608032227 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 16 ...
# The training process took 0.2899467945098877 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 17 ...
# The training process took 0.2415790557861328 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 18 ...
# The training process took 0.29328060150146484 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 19 ...
# The training process took 0.2552649974822998 seconds.
# Best validation accuracy: 9.8%.
# ***********************************************
# Best accuracy after random mutation: 65.2
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.21309661865234375 seconds.
# Best validation accuracy: 9.8%.
# *** Improving validation accuracy: 9.8.
# Chromosome 1 ...
# The training process took 0.23031854629516602 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 2 ...
# The training process took 0.20679044723510742 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 3 ...
# The training process took 0.19028711318969727 seconds.
# Best validation accuracy: 57.4%.
# *** Improving validation accuracy: 57.4.
# Chromosome 4 ...
# The training process took 0.2255713939666748 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 5 ...
# The training process took 0.20973587036132812 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 6 ...
# The training process took 0.22664165496826172 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 7 ...
# The training process took 0.209791898727417 seconds.
# Best validation accuracy: 20.8%.
# Chromosome 8 ...
# The training process took 0.23560357093811035 seconds.
# Best validation accuracy: 48.9%.
# Chromosome 9 ...
# The training process took 0.2505977153778076 seconds.
# Best validation accuracy: 10.9%.
# ***********************************************
# Best accuracy after differential search: 57.4
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 3.
# ======================================
# Best accuracy so far: 65.2
# ======================================
# Chromosome 0 ...
# The training process took 0.2545616626739502 seconds.
# Best validation accuracy: 10.0%.
# *** Improving validation accuracy: 10.0.
# Chromosome 1 ...
# The training process took 0.23678159713745117 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 2 ...
# The training process took 0.21579265594482422 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 3 ...
# The training process took 0.27139782905578613 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 4 ...
# The training process took 0.19292068481445312 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 5 ...
# The training process took 0.20663976669311523 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 6 ...
# The training process took 0.22855257987976074 seconds.
# Best validation accuracy: 67.60000000000001%.
# *** Improving validation accuracy: 67.60000000000001.
# Chromosome 7 ...
# The training process took 0.27304863929748535 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 8 ...
# The training process took 0.22212457656860352 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 9 ...
# The training process took 0.20661544799804688 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 10 ...
# The training process took 0.20882487297058105 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 11 ...
# The training process took 0.2090137004852295 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 12 ...
# The training process took 0.22927618026733398 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 13 ...
# The training process took 0.24349284172058105 seconds.
# Best validation accuracy: 14.299999999999999%.
# Chromosome 14 ...
# The training process took 0.254793643951416 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 15 ...
# The training process took 0.2620234489440918 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 16 ...
# The training process took 0.2613821029663086 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 17 ...
# The training process took 0.24390268325805664 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 18 ...
# The training process took 0.24199199676513672 seconds.
# Best validation accuracy: 10.5%.
# Chromosome 19 ...
# The training process took 0.2182176113128662 seconds.
# Best validation accuracy: 10.9%.
# ***********************************************
# Best accuracy after random mutation: 67.60000000000001
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.23659944534301758 seconds.
# Best validation accuracy: 9.8%.
# *** Improving validation accuracy: 9.8.
# Chromosome 1 ...
# The training process took 0.23732471466064453 seconds.
# Best validation accuracy: 47.0%.
# *** Improving validation accuracy: 47.0.
# Chromosome 2 ...
# The training process took 0.2432236671447754 seconds.
# Best validation accuracy: 19.7%.
# Chromosome 3 ...
# The training process took 0.22438955307006836 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 4 ...
# The training process took 0.24029231071472168 seconds.
# Best validation accuracy: 31.900000000000002%.
# Chromosome 5 ...
# The training process took 0.23161864280700684 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 6 ...
# The training process took 0.24184489250183105 seconds.
# Best validation accuracy: 54.7%.
# *** Improving validation accuracy: 54.7.
# Chromosome 7 ...
# The training process took 0.2300565242767334 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 8 ...
# The training process took 0.2160332202911377 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 9 ...
# The training process took 0.24864530563354492 seconds.
# Best validation accuracy: 20.4%.
# ***********************************************
# Best accuracy after differential search: 54.7
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 4.
# ======================================
# Best accuracy so far: 67.60000000000001
# ======================================
# Chromosome 0 ...
# The training process took 0.2355489730834961 seconds.
# Best validation accuracy: 10.7%.
# *** Improving validation accuracy: 10.7.
# Chromosome 1 ...
# The training process took 0.22409296035766602 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 2 ...
# The training process took 0.2261333465576172 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 3 ...
# The training process took 0.21004438400268555 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 4 ...
# The training process took 0.2536745071411133 seconds.
# Best validation accuracy: 13.4%.
# *** Improving validation accuracy: 13.4.
# Chromosome 5 ...
# The training process took 0.28716087341308594 seconds.
# Best validation accuracy: 57.199999999999996%.
# *** Improving validation accuracy: 57.199999999999996.
# Chromosome 6 ...
# The training process took 0.27742576599121094 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 7 ...
# The training process took 0.2835254669189453 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 8 ...
# The training process took 0.20703887939453125 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 9 ...
# The training process took 0.2332744598388672 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 10 ...
# The training process took 0.20506882667541504 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 11 ...
# The training process took 0.23312020301818848 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 12 ...
# The training process took 0.24065852165222168 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 13 ...
# The training process took 0.2571382522583008 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 14 ...
# The training process took 0.21323251724243164 seconds.
# Best validation accuracy: 26.700000000000003%.
# Chromosome 15 ...
# The training process took 0.26029205322265625 seconds.
# Best validation accuracy: 73.1%.
# *** Improving validation accuracy: 73.1.
# Chromosome 16 ...
# The training process took 0.21683287620544434 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 17 ...
# The training process took 0.1984999179840088 seconds.
# Best validation accuracy: 59.0%.
# Chromosome 18 ...
# The training process took 0.23825788497924805 seconds.
# Best validation accuracy: 15.4%.
# Chromosome 19 ...
# The training process took 0.22815871238708496 seconds.
# Best validation accuracy: 29.299999999999997%.
# ***********************************************
# Best accuracy after random mutation: 73.1
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.26799821853637695 seconds.
# Best validation accuracy: 62.5%.
# *** Improving validation accuracy: 62.5.
# Chromosome 1 ...
# The training process took 0.2674694061279297 seconds.
# Best validation accuracy: 51.5%.
# Chromosome 2 ...
# The training process took 0.2492372989654541 seconds.
# Best validation accuracy: 33.7%.
# Chromosome 3 ...
# The training process took 0.2537219524383545 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 4 ...
# The training process took 0.25098419189453125 seconds.
# Best validation accuracy: 20.5%.
# Chromosome 5 ...
# The training process took 0.2639122009277344 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 6 ...
# The training process took 0.24843740463256836 seconds.
# Best validation accuracy: 11.600000000000001%.
# Chromosome 7 ...
# The training process took 0.26442384719848633 seconds.
# Best validation accuracy: 55.1%.
# Chromosome 8 ...
# The training process took 0.26760005950927734 seconds.
# Best validation accuracy: 59.099999999999994%.
# Chromosome 9 ...
# The training process took 0.2404780387878418 seconds.
# Best validation accuracy: 71.5%.
# *** Improving validation accuracy: 71.5.
# ***********************************************
# Best accuracy after differential search: 71.5
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 5.
# ======================================
# Best accuracy so far: 73.1
# ======================================
# Chromosome 0 ...
# The training process took 0.23375821113586426 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 1 ...
# The training process took 0.2257213592529297 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 2 ...
# The training process took 0.19737982749938965 seconds.
# Best validation accuracy: 72.2%.
# *** Improving validation accuracy: 72.2.
# Chromosome 3 ...
# The training process took 0.2568020820617676 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 4 ...
# The training process took 0.2190690040588379 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 5 ...
# The training process took 0.2525804042816162 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 6 ...
# The training process took 0.28178930282592773 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 7 ...
# The training process took 0.22760748863220215 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 8 ...
# The training process took 0.2734553813934326 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 9 ...
# The training process took 0.2915351390838623 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 10 ...
# The training process took 0.2812833786010742 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 11 ...
# The training process took 0.1953883171081543 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 12 ...
# The training process took 0.2649965286254883 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 13 ...
# The training process took 0.2781832218170166 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 14 ...
# The training process took 0.20322966575622559 seconds.
# Best validation accuracy: 57.4%.
# Chromosome 15 ...
# The training process took 0.2582736015319824 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 16 ...
# The training process took 0.20747780799865723 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 17 ...
# The training process took 0.19649505615234375 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 18 ...
# The training process took 0.25153493881225586 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 19 ...
# The training process took 0.261063814163208 seconds.
# Best validation accuracy: 51.300000000000004%.
# ***********************************************
# Best accuracy after random mutation: 72.2
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.21372151374816895 seconds.
# Best validation accuracy: 9.8%.
# *** Improving validation accuracy: 9.8.
# Chromosome 1 ...
# The training process took 0.19507646560668945 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 2 ...
# The training process took 0.2277686595916748 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 3 ...
# The training process took 0.21348023414611816 seconds.
# Best validation accuracy: 36.9%.
# *** Improving validation accuracy: 36.9.
# Chromosome 4 ...
# The training process took 0.18802475929260254 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 5 ...
# The training process took 0.22261500358581543 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 6 ...
# The training process took 0.21905064582824707 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 7 ...
# The training process took 0.2061138153076172 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 8 ...
# The training process took 0.20700287818908691 seconds.
# Best validation accuracy: 55.7%.
# *** Improving validation accuracy: 55.7.
# Chromosome 9 ...
# The training process took 0.2118828296661377 seconds.
# Best validation accuracy: 56.99999999999999%.
# *** Improving validation accuracy: 56.99999999999999.
# ***********************************************
# Best accuracy after differential search: 56.99999999999999
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 6.
# ======================================
# Best accuracy so far: 73.1
# ======================================
# Chromosome 0 ...
# The training process took 0.22393345832824707 seconds.
# Best validation accuracy: 51.9%.
# *** Improving validation accuracy: 51.9.
# Chromosome 1 ...
# The training process took 0.2432544231414795 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 2 ...
# The training process took 0.27108144760131836 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 3 ...
# The training process took 0.2021477222442627 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 4 ...
# The training process took 0.2542877197265625 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 5 ...
# The training process took 0.24341416358947754 seconds.
# Best validation accuracy: 16.900000000000002%.
# Chromosome 6 ...
# The training process took 0.2717409133911133 seconds.
# Best validation accuracy: 10.100000000000001%.
# Chromosome 7 ...
# The training process took 0.24202561378479004 seconds.
# Best validation accuracy: 33.900000000000006%.
# Chromosome 8 ...
# The training process took 0.2714042663574219 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 9 ...
# The training process took 0.26427292823791504 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 10 ...
# The training process took 0.26252055168151855 seconds.
# Best validation accuracy: 55.50000000000001%.
# *** Improving validation accuracy: 55.50000000000001.
# Chromosome 11 ...
# The training process took 0.21264147758483887 seconds.
# Best validation accuracy: 31.3%.
# Chromosome 12 ...
# The training process took 0.23978328704833984 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 13 ...
# The training process took 0.28107428550720215 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 14 ...
# The training process took 0.2574639320373535 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 15 ...
# The training process took 0.27642107009887695 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 16 ...
# The training process took 0.22548627853393555 seconds.
# Best validation accuracy: 33.5%.
# Chromosome 17 ...
# The training process took 0.22192621231079102 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 18 ...
# The training process took 0.30199313163757324 seconds.
# Best validation accuracy: 21.5%.
# Chromosome 19 ...
# The training process took 0.29212331771850586 seconds.
# Best validation accuracy: 10.7%.
# ***********************************************
# Best accuracy after random mutation: 55.50000000000001
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.3044159412384033 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 1 ...
# The training process took 0.27460145950317383 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 2 ...
# The training process took 0.25672149658203125 seconds.
# Best validation accuracy: 31.3%.
# *** Improving validation accuracy: 31.3.
# Chromosome 3 ...
# The training process took 0.2663133144378662 seconds.
# Best validation accuracy: 42.199999999999996%.
# *** Improving validation accuracy: 42.199999999999996.
# Chromosome 4 ...
# The training process took 0.19433331489562988 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 5 ...
# The training process took 0.2624533176422119 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 6 ...
# The training process took 0.2465057373046875 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 7 ...
# The training process took 0.21306610107421875 seconds.
# Best validation accuracy: 12.7%.
# Chromosome 8 ...
# The training process took 0.18912458419799805 seconds.
# Best validation accuracy: 56.99999999999999%.
# *** Improving validation accuracy: 56.99999999999999.
# Chromosome 9 ...
# The training process took 0.21164655685424805 seconds.
# Best validation accuracy: 19.3%.
# ***********************************************
# Best accuracy after differential search: 56.99999999999999
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 7.
# ======================================
# Best accuracy so far: 73.1
# ======================================
# Chromosome 0 ...
# The training process took 0.2201223373413086 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 1 ...
# The training process took 0.30149102210998535 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 2 ...
# The training process took 0.21441936492919922 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 3 ...
# The training process took 0.2705249786376953 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 4 ...
# The training process took 0.28539609909057617 seconds.
# Best validation accuracy: 11.0%.
# *** Improving validation accuracy: 11.0.
# Chromosome 5 ...
# The training process took 0.2433934211730957 seconds.
# Best validation accuracy: 37.6%.
# *** Improving validation accuracy: 37.6.
# Chromosome 6 ...
# The training process took 0.2359936237335205 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 7 ...
# The training process took 0.24780678749084473 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 8 ...
# The training process took 0.2048192024230957 seconds.
# Best validation accuracy: 36.5%.
# Chromosome 9 ...
# The training process took 0.2633805274963379 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 10 ...
# The training process took 0.24708199501037598 seconds.
# Best validation accuracy: 21.5%.
# Chromosome 11 ...
# The training process took 0.21157455444335938 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 12 ...
# The training process took 0.27881431579589844 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 13 ...
# The training process took 0.21124792098999023 seconds.
# Best validation accuracy: 31.900000000000002%.
# Chromosome 14 ...
# The training process took 0.2605621814727783 seconds.
# Best validation accuracy: 33.7%.
# Chromosome 15 ...
# The training process took 0.21463322639465332 seconds.
# Best validation accuracy: 11.700000000000001%.
# Chromosome 16 ...
# The training process took 0.3173398971557617 seconds.
# Best validation accuracy: 72.8%.
# *** Improving validation accuracy: 72.8.
# Chromosome 17 ...
# The training process took 0.34418225288391113 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 18 ...
# The training process took 0.3260490894317627 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 19 ...
# The training process took 0.26262354850769043 seconds.
# Best validation accuracy: 10.7%.
# ***********************************************
# Best accuracy after random mutation: 72.8
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.2853999137878418 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 1 ...
# The training process took 0.2566089630126953 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 2 ...
# The training process took 0.20876097679138184 seconds.
# Best validation accuracy: 50.8%.
# *** Improving validation accuracy: 50.8.
# Chromosome 3 ...
# The training process took 0.26608705520629883 seconds.
# Best validation accuracy: 25.7%.
# Chromosome 4 ...
# The training process took 0.2882654666900635 seconds.
# Best validation accuracy: 27.500000000000004%.
# Chromosome 5 ...
# The training process took 0.263134241104126 seconds.
# Best validation accuracy: 21.2%.
# Chromosome 6 ...
# The training process took 0.1951313018798828 seconds.
# Best validation accuracy: 52.1%.
# *** Improving validation accuracy: 52.1.
# Chromosome 7 ...
# The training process took 0.29358959197998047 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 8 ...
# The training process took 0.18832945823669434 seconds.
# Best validation accuracy: 63.1%.
# *** Improving validation accuracy: 63.1.
# Chromosome 9 ...
# The training process took 0.2617497444152832 seconds.
# Best validation accuracy: 9.8%.
# ***********************************************
# Best accuracy after differential search: 63.1
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 8.
# ======================================
# Best accuracy so far: 73.1
# ======================================
# Chromosome 0 ...
# The training process took 0.2600739002227783 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 1 ...
# The training process took 0.2702362537384033 seconds.
# Best validation accuracy: 19.6%.
# *** Improving validation accuracy: 19.6.
# Chromosome 2 ...
# The training process took 0.2510099411010742 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 3 ...
# The training process took 0.26935362815856934 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 4 ...
# The training process took 0.23348045349121094 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 5 ...
# The training process took 0.24820423126220703 seconds.
# Best validation accuracy: 18.8%.
# Chromosome 6 ...
# The training process took 0.2591419219970703 seconds.
# Best validation accuracy: 40.0%.
# *** Improving validation accuracy: 40.0.
# Chromosome 7 ...
# The training process took 0.2579340934753418 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 8 ...
# The training process took 0.23505830764770508 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 9 ...
# The training process took 0.2669205665588379 seconds.
# Best validation accuracy: 64.60000000000001%.
# *** Improving validation accuracy: 64.60000000000001.
# Chromosome 10 ...
# The training process took 0.21326375007629395 seconds.
# Best validation accuracy: 29.9%.
# Chromosome 11 ...
# The training process took 0.21586346626281738 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 12 ...
# The training process took 0.2142775058746338 seconds.
# Best validation accuracy: 60.699999999999996%.
# Chromosome 13 ...
# The training process took 0.24164772033691406 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 14 ...
# The training process took 0.22184348106384277 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 15 ...
# The training process took 0.19781947135925293 seconds.
# Best validation accuracy: 18.9%.
# Chromosome 16 ...
# The training process took 0.23976731300354004 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 17 ...
# The training process took 0.23337745666503906 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 18 ...
# The training process took 0.19832491874694824 seconds.
# Best validation accuracy: 11.1%.
# Chromosome 19 ...
# The training process took 0.2266557216644287 seconds.
# Best validation accuracy: 10.7%.
# ***********************************************
# Best accuracy after random mutation: 64.60000000000001
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.2558934688568115 seconds.
# Best validation accuracy: 10.0%.
# *** Improving validation accuracy: 10.0.
# Chromosome 1 ...
# The training process took 0.2600829601287842 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 2 ...
# The training process took 0.2740964889526367 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 3 ...
# The training process took 0.2424476146697998 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 4 ...
# The training process took 0.24397706985473633 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 5 ...
# The training process took 0.27105188369750977 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 6 ...
# The training process took 0.2617321014404297 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 7 ...
# The training process took 0.2617616653442383 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 8 ...
# The training process took 0.24697184562683105 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 9 ...
# The training process took 0.24918794631958008 seconds.
# Best validation accuracy: 10.0%.
# ***********************************************
# Best accuracy after differential search: 10.9
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 9.
# ======================================
# Best accuracy so far: 73.1
# ======================================
# Chromosome 0 ...
# The training process took 0.24801898002624512 seconds.
# Best validation accuracy: 9.8%.
# *** Improving validation accuracy: 9.8.
# Chromosome 1 ...
# The training process took 0.19307518005371094 seconds.
# Best validation accuracy: 32.800000000000004%.
# *** Improving validation accuracy: 32.800000000000004.
# Chromosome 2 ...
# The training process took 0.22765779495239258 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 3 ...
# The training process took 0.24107003211975098 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 4 ...
# The training process took 0.23713421821594238 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 5 ...
# The training process took 0.21990227699279785 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 6 ...
# The training process took 0.2657632827758789 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 7 ...
# The training process took 0.2574930191040039 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 8 ...
# The training process took 0.2658708095550537 seconds.
# Best validation accuracy: 18.0%.
# Chromosome 9 ...
# The training process took 0.1979973316192627 seconds.
# Best validation accuracy: 49.3%.
# *** Improving validation accuracy: 49.3.
# Chromosome 10 ...
# The training process took 0.1936807632446289 seconds.
# Best validation accuracy: 10.8%.
# Chromosome 11 ...
# The training process took 0.2622976303100586 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 12 ...
# The training process took 0.27016282081604004 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 13 ...
# The training process took 0.24425435066223145 seconds.
# Best validation accuracy: 39.6%.
# Chromosome 14 ...
# The training process took 0.23076581954956055 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 15 ...
# The training process took 0.23805594444274902 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 16 ...
# The training process took 0.2762913703918457 seconds.
# Best validation accuracy: 66.9%.
# *** Improving validation accuracy: 66.9.
# Chromosome 17 ...
# The training process took 0.21460247039794922 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 18 ...
# The training process took 0.2557821273803711 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 19 ...
# The training process took 0.2858316898345947 seconds.
# Best validation accuracy: 10.9%.
# ***********************************************
# Best accuracy after random mutation: 66.9
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.26252150535583496 seconds.
# Best validation accuracy: 60.6%.
# *** Improving validation accuracy: 60.6.
# Chromosome 1 ...
# The training process took 0.23697543144226074 seconds.
# Best validation accuracy: 45.2%.
# Chromosome 2 ...
# The training process took 0.2559685707092285 seconds.
# Best validation accuracy: 64.3%.
# *** Improving validation accuracy: 64.3.
# Chromosome 3 ...
# The training process took 0.2418360710144043 seconds.
# Best validation accuracy: 54.50000000000001%.
# Chromosome 4 ...
# The training process took 0.2900567054748535 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 5 ...
# The training process took 0.2592015266418457 seconds.
# Best validation accuracy: 70.0%.
# *** Improving validation accuracy: 70.0.
# Chromosome 6 ...
# The training process took 0.256791353225708 seconds.
# Best validation accuracy: 70.5%.
# *** Improving validation accuracy: 70.5.
# Chromosome 7 ...
# The training process took 0.2554957866668701 seconds.
# Best validation accuracy: 10.5%.
# Chromosome 8 ...
# The training process took 0.2736635208129883 seconds.
# Best validation accuracy: 72.3%.
# *** Improving validation accuracy: 72.3.
# Chromosome 9 ...
# The training process took 0.23653006553649902 seconds.
# Best validation accuracy: 19.400000000000002%.
# ***********************************************
# Best accuracy after differential search: 72.3
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 10.
# ======================================
# Best accuracy so far: 73.1
# ======================================
# Chromosome 0 ...
# The training process took 0.2191476821899414 seconds.
# Best validation accuracy: 10.7%.
# *** Improving validation accuracy: 10.7.
# Chromosome 1 ...
# The training process took 0.20927071571350098 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 2 ...
# The training process took 0.2142937183380127 seconds.
# Best validation accuracy: 27.700000000000003%.
# *** Improving validation accuracy: 27.700000000000003.
# Chromosome 3 ...
# The training process took 0.20501255989074707 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 4 ...
# The training process took 0.21951532363891602 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 5 ...
# The training process took 0.2684779167175293 seconds.
# Best validation accuracy: 62.6%.
# *** Improving validation accuracy: 62.6.
# Chromosome 6 ...
# The training process took 0.28981757164001465 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 7 ...
# The training process took 0.2496781349182129 seconds.
# Best validation accuracy: 47.099999999999994%.
# Chromosome 8 ...
# The training process took 0.2617769241333008 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 9 ...
# The training process took 0.22954702377319336 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 10 ...
# The training process took 0.26293110847473145 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 11 ...
# The training process took 0.24471712112426758 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 12 ...
# ...
# The training process took 0.19446015357971191 seconds.
# Best validation accuracy: 51.2%.
# *** Improving validation accuracy: 51.2.
# Chromosome 1 ...
# The training process took 0.21973466873168945 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 2 ...
# The training process took 0.24261212348937988 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 3 ...
# The training process took 0.27944469451904297 seconds.
# Best validation accuracy: 11.3%.
# Chromosome 4 ...
# The training process took 0.25937795639038086 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 5 ...
# The training process took 0.28208303451538086 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 6 ...
# The training process took 0.2655365467071533 seconds.
# Best validation accuracy: 37.3%.
# Chromosome 7 ...
# The training process took 0.28586649894714355 seconds.
# Best validation accuracy: 15.299999999999999%.
# Chromosome 8 ...
# The training process took 0.29307103157043457 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 9 ...
# The training process took 0.2277212142944336 seconds.
# Best validation accuracy: 64.1%.
# *** Improving validation accuracy: 64.1.
# Chromosome 10 ...
# The training process took 0.26398563385009766 seconds.
# Best validation accuracy: 25.4%.
# Chromosome 11 ...
# The training process took 0.2424006462097168 seconds.
# Best validation accuracy: 26.6%.
# Chromosome 12 ...
# The training process took 0.26212477684020996 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 13 ...
# The training process took 0.20863008499145508 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 14 ...
# The training process took 0.20102429389953613 seconds.
# Best validation accuracy: 31.5%.
# Chromosome 15 ...
# The training process took 0.2893035411834717 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 16 ...
# The training process took 0.2944679260253906 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 17 ...
# The training process took 0.25533175468444824 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 18 ...
# The training process took 0.2369081974029541 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 19 ...
# The training process took 0.2844376564025879 seconds.
# Best validation accuracy: 18.5%.
# ***********************************************
# Best accuracy after random mutation: 64.1
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.24662995338439941 seconds.
# Best validation accuracy: 70.7%.
# *** Improving validation accuracy: 70.7.
# Chromosome 1 ...
# The training process took 0.22288179397583008 seconds.
# Best validation accuracy: 63.6%.
# Chromosome 2 ...
# The training process took 0.23780465126037598 seconds.
# Best validation accuracy: 70.6%.
# Chromosome 3 ...
# The training process took 0.2306346893310547 seconds.
# Best validation accuracy: 20.9%.
# Chromosome 4 ...
# The training process took 0.25548219680786133 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 5 ...
# The training process took 0.2399742603302002 seconds.
# Best validation accuracy: 19.6%.
# Chromosome 6 ...
# The training process took 0.24527955055236816 seconds.
# Best validation accuracy: 15.299999999999999%.
# Chromosome 7 ...
# The training process took 0.22319674491882324 seconds.
# Best validation accuracy: 67.9%.
# Chromosome 8 ...
# The training process took 0.24242353439331055 seconds.
# Best validation accuracy: 41.6%.
# Chromosome 9 ...
# The training process took 0.22425580024719238 seconds.
# Best validation accuracy: 27.0%.
# ***********************************************
# Best accuracy after differential search: 70.7
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 19.
# ======================================
# Best accuracy so far: 74.5
# ======================================
# Chromosome 0 ...
# The training process took 0.2453327178955078 seconds.
# Best validation accuracy: 61.4%.
# *** Improving validation accuracy: 61.4.
# Chromosome 1 ...
# The training process took 0.269989013671875 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 2 ...
# The training process took 0.2252655029296875 seconds.
# Best validation accuracy: 15.299999999999999%.
# Chromosome 3 ...
# The training process took 0.23518037796020508 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 4 ...
# The training process took 0.2709660530090332 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 5 ...
# The training process took 0.25509047508239746 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 6 ...
# The training process took 0.24935579299926758 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 7 ...
# The training process took 0.21563935279846191 seconds.
# Best validation accuracy: 11.4%.
# Chromosome 8 ...
# The training process took 0.2813243865966797 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 9 ...
# The training process took 0.2560560703277588 seconds.
# Best validation accuracy: 28.1%.
# Chromosome 10 ...
# The training process took 0.2484445571899414 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 11 ...
# The training process took 0.2622239589691162 seconds.
# Best validation accuracy: 16.3%.
# Chromosome 12 ...
# The training process took 0.20743632316589355 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 13 ...
# The training process took 0.20136690139770508 seconds.
# Best validation accuracy: 19.400000000000002%.
# Chromosome 14 ...
# The training process took 0.20206856727600098 seconds.
# Best validation accuracy: 39.5%.
# Chromosome 15 ...
# The training process took 0.24024343490600586 seconds.
# Best validation accuracy: 57.4%.
# Chromosome 16 ...
# The training process took 0.2081899642944336 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 17 ...
# The training process took 0.20887541770935059 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 18 ...
# The training process took 0.2508878707885742 seconds.
# Best validation accuracy: 36.9%.
# Chromosome 19 ...
# The training process took 0.2807002067565918 seconds.
# Best validation accuracy: 11.0%.
# ***********************************************
# Best accuracy after random mutation: 61.4
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.22641634941101074 seconds.
# Best validation accuracy: 10.7%.
# *** Improving validation accuracy: 10.7.
# Chromosome 1 ...
# The training process took 0.25302815437316895 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 2 ...
# The training process took 0.3020343780517578 seconds.
# Best validation accuracy: 19.2%.
# *** Improving validation accuracy: 19.2.
# Chromosome 3 ...
# The training process took 0.23825311660766602 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 4 ...
# The training process took 0.28327250480651855 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 5 ...
# The training process took 0.2307586669921875 seconds.
# Best validation accuracy: 14.2%.
# Chromosome 6 ...
# The training process took 0.22083520889282227 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 7 ...
# The training process took 0.2368183135986328 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 8 ...
# The training process took 0.25499701499938965 seconds.
# Best validation accuracy: 31.3%.
# *** Improving validation accuracy: 31.3.
# Chromosome 9 ...
# The training process took 0.26583003997802734 seconds.
# Best validation accuracy: 62.4%.
# *** Improving validation accuracy: 62.4.
# ***********************************************
# Best accuracy after differential search: 62.4
# ***********************************************
# =====================================================
# Architectural optimization total time: 151.6624870300293.
# =====================================================
# ======================================
# Best accuracy so far: 74.5
# ======================================
# Computing the final test ...
# The training process took 28.151176691055298 seconds.
# =====================================
# Training accuracies
# =====================================
# [87.0, 96.0, 99.0, 96.0, 85.0, 95.0, 95.0, 86.0, 77.0, 96.0, 99.0, 100.0, 93.0, 100.0, 100.0, 100.0, 90.0, 98.0, 97.0, 99.0, 100.0, 99.0, 92.0, 89.0, 99.0, 99.0, 90.0, 99.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 97.0, 96.0, 96.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 98.0, 90.0, 96.0, 100.0, 100.0, 100.0, 99.0, 99.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 99.0, 99.0, 99.0, 99.0, 100.0, 100.0, 100.0, 100.0, 100.0, 99.0, 99.0, 99.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 98.0, 96.0, 94.0, 96.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 10 ...
# =====================================
# Best training parameters
# =====================================
# (0.8193405650330787, 0.5904262254284847, 5, 0.6617063159472785, 0.04578286792091881)
# =====================================
# Best model
# =====================================
# GBNDM(
#   (pre_branch_layers): ModuleList(
#     (0): Sequential(
#       (0): Identity()
#       (1): CELU(alpha=1.3080715469945816)
#     )
#     (1): Identity()
#   )
#   (branches): ModuleList(
#     (0): ModuleList(
#       (0): Sequential(
#         (0): Linear(in_features=784, out_features=77, bias=True)
#         (1): LeakyReLU(negative_slope=0.36127811771832163)
#       )
#       (1): Sequential(
#         (0): Linear(in_features=77, out_features=41, bias=True)
#         (1): ReLU()
#       )
#       (2): Sequential(
#         (0): Linear(in_features=41, out_features=90, bias=True)
#         (1): Softplus(beta=0.7232496242243169, threshold=20)
#       )
#     )
#     (1): ModuleList(
#       (0): Sequential(
#         (0): Elem_Scaling_1D()
#         (1): CELU(alpha=1.4704279635867803)
#       )
#     )
#     (2): ModuleList(
#       (0): Sequential(
#         (0): Linear(in_features=784, out_features=38, bias=True)
#         (1): Hardshrink(1.5089451895636579)
#       )
#       (1): Sequential(
#         (0): Elem_Scaling_1D()
#         (1): ELU(alpha=1.0875745080370662)
#       )
#       (2): Sequential(
#         (0): Identity()
#         (1): ReLU()
#       )
#     )
#     (3): ModuleList(
#       (0): Sequential(
#         (0): Elem_Scaling_1D()
#         (1): Softplus(beta=1.8224916601280439, threshold=9.329866389719056)
#       )
#       (1): Sequential(
#         (0): Linear(in_features=784, out_features=26, bias=True)
#         (1): Threshold(threshold=1.767406028626584, value=1.209642957961823)
#       )
#     )
#     (4): ModuleList(
#       (0): Sequential(
#         (0): Elem_Scaling_1D()
#         (1): Sigmoid()
#       )
#       (1): Sequential(
#         (0): Linear(in_features=784, out_features=54, bias=True)
#         (1): Softsign()
#       )
#       (2): Sequential(
#         (0): Linear(in_features=54, out_features=71, bias=True)
#         (1): Softplus(beta=0.10634981100179025, threshold=20)
#       )
#       (3): Sequential(
#         (0): Identity()
#         (1): Softsign()
#       )
#       (4): Sequential(
#         (0): Linear(in_features=71, out_features=68, bias=True)
#         (1): Softmin()
#       )
#     )
#     (5): ModuleList(
#       (0): Sequential(
#         (0): Identity()
#         (1): ELU(alpha=0.6568233751165857)
#       )
#       (1): Identity()
#       (2): Sequential(
#         (0): Linear(in_features=784, out_features=43, bias=True)
#         (1): ReLU()
#       )
#       (3): Sequential(
#         (0): Linear(in_features=43, out_features=80, bias=True)
#         (1): ReLU6()
#       )
#       (4): Sequential(
#         (0): Linear(in_features=80, out_features=30, bias=True)
#         (1): LeakyReLU(negative_slope=0.05263510250300428)
#       )
#     )
#     (6): ModuleList(
#       (0): Sequential(
#         (0): Linear(in_features=784, out_features=40, bias=True)
#         (1): Tanh()
#       )
#       (1): Sequential(
#         (0): Linear(in_features=40, out_features=84, bias=True)
#         (1): SELU()
#       )
#       (2): Sequential(
#         (0): Linear(in_features=84, out_features=10, bias=True)
#         (1): Hardtanh(min_val=1.4070604742934347, max_val=1.534801313539709)
#       )
#     )
#   )
#   (post_branch_layers): ModuleList(
#     (0): Sequential(
#       (0): Elem_Scaling_1D()
#       (1): PReLU(num_parameters=1)
#     )
#   )
#   (final_layer): Linear(in_features=1046, out_features=10, bias=True)
# )
# =====================================
# Test accuracies
# =====================================
# Model with best validation accuracy:
#
# Test set: Average loss: 1.1866, Accuracy (at final epoch): 7601/10000 (76%)
#
# Model at the end of training:
#
# Test set: Average loss: 2.3085, Accuracy (at final epoch): 7506/10000 (75%)
#
# Saving the best chromosome in the root directory (My Drive) ...
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
